# %% [markdown]
# # Capítol 5 - Dividir i Vèncer

# %% [markdown]
# ## 5.23 Sumatori parcial màxim

# %% [markdown]
# L'objectiu d'aquest problema és trobar la subseqüència de suma màxima dins una llista.

# %%
# Solució força bruta
def sumatori_parcial_maxim_forca_bruta(llista):
    """
    Aquesta funció troba el sumatori parcial (dels enters consecutius a la llista) de valor màxim.
    
    Parameters
    ----------
    llista: list
    
    Returns
    -------
    max_sum: int
    """
    return max_sum

# %%
assert sumatori_parcial_maxim_forca_bruta([-3, 2, -1, 9, 8 , -1, -1,-1, -105]) == 18

# %% [markdown]
# Resol el problema del sumatori parcial màxim usant un algorisme que implementi l’estratègia de dividir i vèncer. Demostra que la complexitat d’aquest algorisme és O(n log(n)).
# Fes servir aquesta plantilla per escriure el teu codi:

# %%
# Solució dividir i vèncer
def sumatori_parcial_divider_vencer(llista):
    """
    Aquesta funció troba el sumatori parcial (dels enters consecutius a la llista) de valor màxim.
    
    Parameters
    ----------
    llista: list
    
    Returns
    -------
    max_sum: int
    """
    return max_sum

# %%
assert sumatori_parcial_divider_vencer([-3, 2, -1, 9, 8 , -1, -1,-1, -105]) == 18

# %%
# Solució Kadane
def sumatori_parcial_kadane(llista): 
    """
    Aquesta funció troba el sumatori parcial (dels enters consecutius a la llista) de valor màxim.
    
    Parameters
    ----------
    llista: list
    
    Returns
    -------
    max_sum: int
    """
        
    return max_sum

# %%
assert sumatori_parcial_kadane([-3, 2, -1, 9, 8 , -1, -1,-1, -105]) == 18
