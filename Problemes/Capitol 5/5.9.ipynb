# %% [markdown]
# # Capítol 5 - Dividir i Vèncer

# %% [markdown]
# ### 5.9 Valor igual al seu índex

# %% [markdown]
# Donada una llista $L$ de $n$ nombres enters ordenats de manera creixent, crea una funció "existeix", que, usant l'estratègia de dividir i vèncer, comprovi si existeix algun element de la llista que compleixi el següent:
#
# $L[i] = i, i ∈ \{0, ..., n-1\}$
#
# L'algorisme proposat ha de tenir complexitat $O(log(n))$.

# %%
def existeix(llista):
    """
    Aquesta funció comprova si existeix un element tal que llista[i] = i.
    
    Parameters
    ----------
    llista: list
    
    Returns
    -------
    bExisteix: bool
    """
    return bExisteix

# %%
    assert existeix([1, 4, 5, 6, 7]) == False
    assert existeix([0, 1, 2, 7]) == True
    assert existeix([-1, 1, 1, 3]) == True
